# %% [markdown]
# # Plotting
#
# Testing `PyPlot.jl` since the Python package `matplotlib` is tricky to install.

# %%
import PyPlot as plt
using Random
Random.seed!(2022)

plt.plot(1:5, rand(1:6, 5))
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fe0a9eac050>

# %%
versioninfo()
# Out:
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#   CPU: 32 × AMD EPYC 7B13
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, znver3)
#   Threads: 32 on 32 virtual cores
# Environment:
#   JULIA_PATH = /usr/local/julia/
#   JULIA_NUM_THREADS = auto

# %%
import Pkg
Pkg.status()
# Out:
# Status `/tmp/cirrus-ci-build/Project.toml`
#   [7073ff75] IJulia v1.24.0
#   [d330b81b] PyPlot v2.11.0
